# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_csv('abc_report.csv', sep=';')
df
# Out:
#     KodeMenu               NamaMenu      Bulan Category Branch  Harga  Total  \
# 0      F0019  Add Bakso Banjir Keju    October     Food  Pandu  15454      5
# 1      F0019  Add Bakso Banjir Keju    October     Food  Pandu  15454      1
# 2      F0019  Add Bakso Banjir Keju  September     Food  Pandu  15454     50
# 3      F0019  Add Bakso Banjir Keju  September     Food  Pandu  15454      1
# 4      B0027        add Bakso keju     October     Food     SW  15454      8
# ..       ...                    ...        ...      ...    ...    ...    ...
# 429    B0098         Tropical Punch  September    Drink     SW  20000      1
# 430    B0079       Tropical Sunrise    October    Drink  Pandu  18182      4
# 431    B0079       Tropical Sunrise  September    Drink  Pandu  18182     11
# 432    B0092       Tropical Sunrise    October    Drink     SW  18182      1
# 433    B0092       Tropical Sunrise  September    Drink     SW  18182     14
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434 entries, 0 to 433
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KodeMenu    434 non-null    object
#  1   NamaMenu    434 non-null    object
#  2   Bulan       434 non-null    object
#  3   Category    434 non-null    object
#  4   Branch      434 non-null    object
#  5   Harga       434 non-null    int64
#  6   Total       434 non-null    int64
#  7   DineIn      434 non-null    int64
#  8   TakeAway    434 non-null    int64
#  9   Gojek/Grab  434 non-null    int64
#  10  _1          434 non-null    int64
#  11  _2          434 non-null    int64
#  12  _3          434 non-null    int64
#  13  TotalHarga  434 non-null    int64
# dtypes: int64(9), object(5)
# memory usage: 47.6+ KB

# %%
df.describe()
# Out:
#               Harga       Total     DineIn    TakeAway  Gojek/Grab  \
# count    434.000000  434.000000  434.00000  434.000000  434.000000
# mean   17364.619816   31.921659   26.81106    1.730415    1.960829
# std     9851.091578   50.630786   43.46102   11.378382    8.574135
# min        0.000000    1.000000   -2.00000    0.000000    0.000000
# 25%     8181.000000    3.000000    3.00000    0.000000    0.000000
# 50%    18182.000000   11.000000   10.00000    0.000000    0.000000
# 75%    23636.000000   34.000000   28.00000    1.000000    0.000000
# max    68182.000000  331.000000  323.00000  215.000000  130.000000
#
#                _1          _2             _3    TotalHarga
# count  434.000000  434.000000     434.000000  4.340000e+02
# mean     0.649770    0.769585   22011.412442  4.169262e+05
# std      4.176467    4.583069   45612.671059  7.168216e+05
# min      0.000000    0.000000       0.000000  0.000000e+00
# 25%      0.000000    0.000000     688.000000  3.903400e+04
# ...

# %%
text = list((df['NamaMenu']+',')*df['Total'])
len(text)
# Out:
# 434

# %%
text[:2]
# Out:
# ['Add Bakso Banjir Keju,Add Bakso Banjir Keju,Add Bakso Banjir Keju,Add Bakso Banjir Keju,Add Bakso Banjir Keju,',
#  'Add Bakso Banjir Keju,']

# %%
list_text = []
textt = []

for i in text :
    i = i.split(',')
    list_text.append(i)
        
for i in list_text:
    for j in i:
        j = j.replace(' ','')
        j = j.replace('Add','')
        if len(j)==0:
            continue
        else:
            textt.append(j)

# %%
len(textt)
# Out:
# 13854

# %%
myset = set(textt)  #cek aja distinct value nya apa aja

# %%
str =  ' '.join(textt)

# %%
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, 
                      background_color='salmon', colormap='Pastel1', collocations=False).generate(str)
# Plot

plt.figure(figsize=(10,15))
plt.imshow(wordcloud)
plt.margins(x=0, y=0)
plt.axis("off")
# Out:
# (-0.5, 2999.5, 1999.5, -0.5)

# %%
drink = df[df["Category"]=='Drink']
food = df[df["Category"]=='Food']

# %%
text_food = list((food['NamaMenu']+',')*food['Total'])
text_drink = list((drink['NamaMenu']+',')*drink['Total'])

# %%
list_text = []
textt = []

for i in text_food :
    i = i.split(',')
    list_text.append(i)
        
for i in list_text:
    for j in i:
        j = j.replace(' ','')
        j = j.replace('Add','')
        if len(j)==0:
            continue
        else:
            textt.append(j)

# %%
str_food =  ' '.join(textt)

# %%
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, 
                      background_color='pink', colormap='crest_r', collocations=False).generate(str_food)
# Plot

plt.figure(figsize=(10,15))
plt.imshow(wordcloud)
plt.margins(x=0, y=0)
plt.axis("off")
# Out:
# (-0.5, 2999.5, 1999.5, -0.5)

# %%
list_text = []
textt = []

for i in text_drink :
    i = i.split(',')
    list_text.append(i)
        
for i in list_text:
    for j in i:
        j = j.replace(' ','')
        j = j.replace('Add','')
        if len(j)==0:
            continue
        else:
            textt.append(j)

# %%
str_drink =  ' '.join(textt)

# %%
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, 
                      background_color='lightgray', colormap='mako', collocations=False).generate(str_drink)
# Plot

plt.figure(figsize=(10,15))
plt.imshow(wordcloud)
plt.margins(x=0, y=0)
plt.axis("off")
# Out:
# (-0.5, 2999.5, 1999.5, -0.5)

# %%
namaMenu = df.groupby(by=["NamaMenu"]).sum()
namaMenu
# Out:
#                           Harga  Total  DineIn  TakeAway  Gojek/Grab  _1  _2  \
# NamaMenu
# Add Bakso Banjir Keju     61816     57      38        18           1   0   0
# Add Bakso Lada Hitam      30908      5       4         1           0   0   0
# Add Bakso Ranjau Hitam    30908     12       7         5           0   0   0
# Add Bakso Urat Berserat   30908     34      27         7           0   0   0
# Add Pentol                12728    410     156       215          25   0  14
# ...                         ...    ...     ...       ...         ...  ..  ..
# Topping Kikil             10908     24      21         0           3   0   0
# Tropical Punch           100000     24      23         1           0   0   0
# Tropical Sunrise          72728     30      30         0           0   0   0
# add Bakso keju            30908     26      24         0           1   1   0
# kerupuk kulit             16364     42      42         0           0   0   0
#
# ...

# %%
sns.scatterplot(data=namaMenu, x='Total', y='TotalHarga')

# %%
sns.regplot(data=namaMenu, x='Total', y='TotalHarga')

# %%
harga_menuu = df[['NamaMenu','Harga']]

# %%
harga_menuu.drop_duplicates()
# Out:
#                    NamaMenu  Harga
# 0     Add Bakso Banjir Keju  15454
# 4           add Bakso keju   15454
# 6      Add Bakso Lada Hitam  15454
# 8    Add Bakso Ranjau Hitam  15454
# 10           Add bakso urat  15454
# ..                      ...    ...
# 418              Teri Medan  10000
# 419                Thai Tea  20000
# 423           Topping Kikil   5454
# 425          Tropical Punch  20000
# 430        Tropical Sunrise  18182
#
# [125 rows x 2 columns]

# %%
harga_menu = pd.merge(namaMenu,  
                      harga_menuu,  
                      on ='NamaMenu',  
                      how ='inner') 
harga_menu = harga_menu.drop_duplicates()

# %%
sns.scatterplot(data=harga_menu, x='Total', y='Harga_y')

# %%
sorted10 = harga_menu.sort_values('TotalHarga', ascending=False)

# %%
top10 = harga_menu.sort_values('TotalHarga', ascending=False).head(10)
top10
# Out:
#                          NamaMenu  Harga_x  Total  DineIn  TakeAway  \
# 86       Bakso Urat Kuah Original    98180    508     394        29
# 82          Bakso Urat Kuah Merah   127272    367     276         8
# 70     Bakso Tampol Kuah Original    72728    618     489        16
# 38       Bakso Keju Kuah Original   122725    437     349        14
# 115  Bomber + Pentol 2 Kuah Merah   127272    178     168         1
# 124      Bomber + Pentol Original    49090    225     209         6
# 56     Bakso Ladahitam Kuah Merah   159090    165     154         2
# 121         Bomber + Pentol Merah    95454    161     149         4
# 264             Mie Ayam Original    98178    325     226        16
# 119    Bomber + Pentol 2 Original    49090    202     180         6
#
#      Gojek/Grab  _1  _2      _3  TotalHarga  Harga_y
# 86           51  18  16  853485    11615375    24545
# 82           59  11  13  937872    10739334    31818
# 70           60  26  27  576506    10659970    18182
# ...

# %%
sns.barplot(data=top10, x='TotalHarga', y='NamaMenu')

# %%
result = sorted10.nlargest(5, columns='TotalHarga')
result
# Out:
#                          NamaMenu  Harga_x  Total  DineIn  TakeAway  \
# 86       Bakso Urat Kuah Original    98180    508     394        29
# 82          Bakso Urat Kuah Merah   127272    367     276         8
# 70     Bakso Tampol Kuah Original    72728    618     489        16
# 38       Bakso Keju Kuah Original   122725    437     349        14
# 115  Bomber + Pentol 2 Kuah Merah   127272    178     168         1
#
#      Gojek/Grab  _1  _2      _3  TotalHarga  Harga_y
# 86           51  18  16  853485    11615375    24545
# 82           59  11  13  937872    10739334    31818
# 70           60  26  27  576506    10659970    18182
# 38           37  19  18  685314    10040851    24545
# 115           8   1   0  259738     5403898    31818

# %%
sorted10.loc[sorted10.NamaMenu.isin(result.NamaMenu), 'TotalHarga'].sum()
# Out:
# 48459428

# %%
sorted10.loc[~sorted10.NamaMenu.isin(result.NamaMenu), 'TotalHarga'].sum()
# Out:
# 137874134

# %%
dictt = {'sum' : [sorted10.loc[sorted10.NamaMenu.isin(result.NamaMenu), 'TotalHarga'].sum(), sorted10.loc[~sorted10.NamaMenu.isin(result.NamaMenu), 'TotalHarga'].sum()]}
dictt
# Out:
# {'sum': [48459428, 137874134]}

# %%
dictt1 = pd.DataFrame(dictt)
dictt1['type'] = ['top5','rest_of_menu']
dictt1
# Out:
#          sum          type
# 0   48459428          top5
# 1  137874134  rest_of_menu

# %%
plt.figure(figsize=(10,5))

values = dictt1['sum']
labels = dictt1['type']
plt.pie(values, labels = labels, autopct='%1.1f%%')
plt.title('Percentage by Severity Description')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
bulan = df.groupby(by=["Bulan"]).sum()
bulan
# Out:
#              Harga  Total  DineIn  TakeAway  Gojek/Grab   _1   _2       _3  \
# Bulan
# October    3622218   3931    2764       161         732  146  128  4949040
# September  3914027   9923    8872       590         119  136  206  4603913
#
#            TotalHarga
# Bulan
# October      48430672
# September   132515312

# %%
sns.barplot(data=bulan, x='TotalHarga', y=bulan.index)

# %%
branch = df.groupby(by=["Branch"]).sum()
branch
# Out:
#           Harga  Total  DineIn  TakeAway  Gojek/Grab   _1   _2       _3  \
# Branch
# Pandu   3735851   7953    6618       560         441    0  334  4880624
# SW      3800394   5901    5018       191         410  282    0  4672329
#
#         TotalHarga
# Branch
# Pandu    100060862
# SW        80885122

# %%
sns.barplot(data=branch, x='TotalHarga', y=branch.index)

# %%
bulan.columns
# Out:
# Index(['Harga', 'Total', 'DineIn', 'TakeAway', 'Gojek/Grab', '_1', '_2', '_3',
#        'TotalHarga'],
#       dtype='object')

# %%
plt.figure(figsize = (8,4))

plt.stackplot(bulan.index ,bulan['DineIn'],bulan['TakeAway'],bulan['Gojek/Grab'],colors=['orange','darkgreen','darkblue'], labels=('DineIn', 'TakeAway', 'Gojek/Grab'))
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(figsize = (8,4))

plt.stackplot(branch.index ,branch['DineIn'],branch['TakeAway'],branch['Gojek/Grab'],colors=['orange','darkgreen','darkblue'], labels=('DineIn', 'TakeAway', 'Gojek/Grab'))
plt.legend(loc='lower left')
plt.show()

# %%
import seaborn as sns

branch_mode = branch[['DineIn', 'TakeAway', 'Gojek/Grab']]

sns.set()
branch_mode.set_index(branch_mode.index).T.plot(kind='bar', stacked=True)
